# %%
import pandas as pd

daily_news = pd.read_csv("../data/gnews_partial.csv")
stock_df = pd.read_csv('../data/stock_data_4years.csv', skiprows=2)

stock_df.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

daily_news.head()
# Out:
#                                                title  \
# 0                             Today in Apple history
# 1  The AI Trade Is Back in Play: 2 Stocks to Buy ...
# 2  China Tariff Easing Spurs Stock Market Surge A...
# 3  Apple Faces New iPhone Fiasco as Update Bricks...
# 4  2 Reasons I'm Considering Apple Stock for a $2...
#
#                                          description  \
# 0  On June 18, 1993, Apple CEO John Sculley gave ...
# 1  Consider Apple (NASDAQ:AAPL) and another cheap...
# 2  The “dream scenario” for tech investors helped...
# 3  Apple (AAPL) faces another wave of challenges,...
# 4  Apple (NASDAQ:AAPL) stock looks like a deep-va...
#
#                                              content           publishedAt  \
# 0  June 18, 1993: John Sculley steps down as Appl...  2025-06-18T14:30:22Z
# 1  The AI (artificial intelligence) trade is gett...  2025-06-13T23:00:00Z
# 2  Topline Stocks surged across the board Monday ...  2025-05-12T04:00:00Z
# 3  Apple (AAPL) faces another wave of challenges,...  2025-04-27T16:35:02Z
# 4  The stock market has continued to experience a...  2025-04-23T14:00:00Z
#
#                    source                                                url
# 0             Cult of Mac  https://www.cultofmac.com/apple-history/john-s...
# 1  The Motley Fool Canada  https://www.fool.ca/2025/06/13/the-ai-trade-is...
# 2                  Forbes  https://www.forbes.com/sites/dereksaul/2025/05...
# 3        Business Insider  https://markets.businessinsider.com/news/stock...
# 4  The Motley Fool Canada  https://www.fool.ca/2025/04/23/2-reasons-im-co...

# %%
import requests
import pandas as pd
import time
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv('NYT_API')
BASE_URL = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

start_date = 20220901
end_date = 20230228

def get_nyt_articles(query="Apple", begin_date=start_date, end_date=end_date, pages=10):
    articles = []

    for page in range(pages):
        params = {
            "q": query,
            "begin_date": begin_date,  # Format: YYYYMMDD
            "end_date": end_date,
            "page": page,
            "api-key": API_KEY
        }

        response = requests.get(BASE_URL, params=params)
        if response.status_code != 200:
            print(f"Failed at page {page}, status code: {response.status_code}")
            break

        docs = response.json().get("response", {}).get("docs", [])
        if not docs:
            print(f"No docs found on page {page}")
            break

        for doc in docs:
            articles.append({
                "title": doc.get("headline", {}).get("main", ""),
                "snippet": doc.get("snippet", ""),
                "pub_date": doc.get("pub_date", ""),
                "web_url": doc.get("web_url", ""),
                "section": doc.get("section_name", ""),
                "source": doc.get("source", "")
            })

        print(f"[✓] Page {page + 1}: {len(docs)} articles fetched")
        time.sleep(20)  # Rate limit: 10 req/min
        
        if response.status_code == 429:
            print("🚫 Rate limit hit! Resting.")
            time.sleep(20)
            continue

    return pd.DataFrame(articles)

# Run the function
df = get_nyt_articles(query="Apple", pages=50)
df.to_csv("nyt_apple22092402.csv", index=False)
print(f"\nSaved {len(df)} articles to nyt_apple22092402.csv")
# Out:
# Failed at page 0, status code: 429
#
# Saved 0 articles to nyt_apple22092402.csv

# %%
apple_news = pd.read_csv('nyt_apple240111.csv')
apple_news.head()
# Out:
#                                                title  \
# 0  7 Apple Picking Tips From the Guy Behind Apple...
# 1            What to Do With That Apple-Picking Haul
# 2                            How Healthy Are Apples?
# 3  U.S. Sues Apple, Accusing It of Maintaining an...
# 4  Apple’s Quarterly Profit Down Because of Tax P...
#
#                                              snippet              pub_date  \
# 0  Brian Frange has been pontificating on apples ...  2024-09-10T09:05:34Z
# 1  Both the fruit and cider go into this supremel...  2024-10-11T15:00:13Z
# 2  They’re America’s most popular fruit. Here’s w...  2024-09-23T09:00:25Z
# 3  The lawsuit caps years of regulatory scrutiny ...  2024-03-21T14:30:39Z
# 4  Sales for the iPhone maker were up 6 percent t...  2024-10-31T21:10:57Z
#
#                                              web_url     section  \
# 0  https://www.nytimes.com/2024/09/10/style/apple...       Style
# 1  https://www.nytimes.com/2024/10/11/dining/what...        Food
# 2  https://www.nytimes.com/2024/09/23/well/eat/ap...        Well
# 3  https://www.nytimes.com/2024/03/21/technology/...  Technology
# 4  https://www.nytimes.com/2024/10/31/technology/...  Technology
#
#                source
# 0  The New York Times
# 1  The New York Times
# 2  The New York Times
# 3  The New York Times
# 4  The New York Times

# %%
apple_news['pub_date'].min()
# Out:
# '2024-01-03T18:21:13Z'

# %%
apple_news['pub_date'].max()
# Out:
# '2024-11-29T12:00:14Z'

# %%
print(apple_news.columns)

print(apple_news['pub_date'].head())

# Convert to datetime
apple_news['pub_date'] = pd.to_datetime(apple_news['pub_date'])

# Sort by date
apple_news = apple_news.sort_values('pub_date')

# View the range of dates
print("Earliest date:", apple_news['pub_date'].min())
print("Latest date:", apple_news['pub_date'].max())

# count articles per year or month
print(apple_news['pub_date'].dt.year.value_counts().sort_index())
print(apple_news['pub_date'].dt.to_period('M').value_counts().sort_index())
# Out:
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2024-09-10T09:05:34Z
# 1    2024-10-11T15:00:13Z
# 2    2024-09-23T09:00:25Z
# 3    2024-03-21T14:30:39Z
# 4    2024-10-31T21:10:57Z
# Name: pub_date, dtype: object
# Earliest date: 2024-01-03 18:21:13+00:00
# Latest date: 2024-11-29 12:00:14+00:00
# pub_date
# 2024    520
# Name: count, dtype: int64
# pub_date
# 2024-01     20
# 2024-02     24
# 2024-03     48
# 2024-04     25
# 2024-05     32
# 2024-06     41
# 2024-07     35
# 2024-08     55
# 2024-09     58
# 2024-10    107
# 2024-11     75
# Freq: M, Name: count, dtype: int64
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\269632180.py:17: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(apple_news['pub_date'].dt.to_period('M').value_counts().sort_index())

# %%
apple_news.shape
# Out:
# (520, 6)

# %%
df_2122 = pd.read_csv('nyt_apple2122.csv')
df_2223 = pd.read_csv('nyt_apple2223.csv')
df_2325 = pd.read_csv('nyt_apple2325.csv')
df_0721 = pd.read_csv('nyt_apple0721.csv')
df_050822 = pd.read_csv('nyt_apple22052208.csv')
df_011124 = pd.read_csv('nyt_apple240111.csv')

# %%
# Function to inspect and process each dataset
def process_news_data(df, name):
    print(f"\n==== {name} ====")
    print(df.columns)
    
    # Check first 5 dates
    print(df['pub_date'].head())
    
    # Convert to datetime
    df['pub_date'] = pd.to_datetime(df['pub_date'], errors='coerce')
    
    # Drop NaT if any failed conversions
    df = df.dropna(subset=['pub_date'])
    
    # Sort by date
    df = df.sort_values('pub_date')
    
    # Print date range
    print("Earliest date:", df['pub_date'].min())
    print("Latest date:", df['pub_date'].max())
    
    # Articles per year
    print("Articles per year:")
    print(df['pub_date'].dt.year.value_counts().sort_index())
    
    # Articles per month
    print("Articles per month:")
    print(df['pub_date'].dt.to_period('M').value_counts().sort_index())
    
    return df  # Return cleaned/sorted version if needed later

# Process each file
df_2122 = process_news_data(df_2122, "NYT Apple 2021-2022")
df_2223 = process_news_data(df_2223, "NYT Apple 2022-2023")
df_2325 = process_news_data(df_2325, "NYT Apple 2023-2025")
df_0721 = process_news_data(df_0721, "NYT Apple 07 2021")
df_050822 = process_news_data(df_050822, "NYT Apple 2022 05 - 2022 08")
df_011124 = process_news_data(df_011124, "NYT Apple 2024 01 - 2024 11")
# Out:
# ==== NYT Apple 2021-2022 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2022-03-11T10:00:21Z
# 1    2021-09-10T15:38:13Z
# 2    2022-03-08T19:35:06Z
# 3    2022-03-01T21:37:14Z
# 4    2022-02-10T21:07:40Z
# Name: pub_date, dtype: object
# Earliest date: 2021-07-20 09:00:07+00:00
# Latest date: 2022-04-26 19:29:18+00:00
# Articles per year:
# pub_date
# 2021    562
# 2022    438
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2021-07     37
# 2021-08     70
# 2021-09    128
# 2021-10    118
# 2021-11    121
# 2021-12     88
# 2022-01    117
# 2022-02    103
# 2022-03    137
# 2022-04     81
# Freq: M, Name: count, dtype: int64
#
# ==== NYT Apple 2022-2023 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2023-10-31T07:00:16Z
# 1    2023-11-29T14:00:10Z
# 2    2023-10-30T19:00:02Z
# 3    2023-12-18T19:12:16Z
# 4    2023-11-12T10:00:21Z
# Name: pub_date, dtype: object
# Earliest date: 2022-04-28 21:11:37+00:00
# Latest date: 2023-12-20 20:00:03+00:00
# Articles per year:
# pub_date
# 2022    117
# 2023    883
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2022-04      1
# 2022-05      6
# 2022-06      7
# 2022-07      6
# 2022-08      1
# 2022-09     21
# 2022-10     20
# 2022-11     27
# 2022-12     28
# 2023-01     29
# 2023-02     36
# 2023-03     41
# 2023-04     49
# 2023-05     49
# 2023-06     92
# 2023-07     83
# 2023-08     77
# 2023-09    125
# 2023-10     97
# 2023-11    154
# 2023-12     51
# Freq: M, Name: count, dtype: int64
#
# ==== NYT Apple 2023-2025 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2025-07-08T22:27:10Z
# 1    2025-05-23T12:46:49Z
# 2    2025-04-22T09:03:37Z
# 3    2025-06-09T18:02:31Z
# 4    2025-05-09T11:00:05Z
# Name: pub_date, dtype: object
# Earliest date: 2023-12-22 10:03:15+00:00
# Latest date: 2025-07-16 11:07:17+00:00
# Articles per year:
# pub_date
# 2023      1
# 2024    302
# 2025    697
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2023-12      1
# 2024-01      1
# 2024-02      5
# 2024-03     16
# 2024-04      6
# 2024-05     11
# 2024-06     15
# 2024-07     12
# 2024-08     27
# 2024-09     33
# 2024-10     44
# 2024-11     52
# 2024-12     80
# 2025-01    116
# 2025-02     94
# 2025-03     94
# 2025-04    122
# 2025-05    119
# 2025-06     94
# 2025-07     58
# Freq: M, Name: count, dtype: int64
#
# ==== NYT Apple 07 2021 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2021-07-28T20:43:55Z
# 1    2021-07-27T20:57:13Z
# 2    2021-07-20T16:06:15Z
# 3    2021-07-20T15:42:40Z
# 4    2021-07-22T09:00:04Z
# Name: pub_date, dtype: object
# Earliest date: 2021-07-19 09:00:10+00:00
# Latest date: 2021-07-30 16:22:17+00:00
# Articles per year:
# pub_date
# 2021    50
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2021-07    50
# Freq: M, Name: count, dtype: int64
#
# ==== NYT Apple 2022 05 - 2022 08 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2022-05-02T11:12:29Z
# 1    2022-05-20T15:50:25Z
# 2    2022-05-17T18:21:56Z
# 3    2022-07-28T21:17:33Z
# 4    2022-06-04T09:00:12Z
# Name: pub_date, dtype: object
# Earliest date: 2022-05-01 09:00:21+00:00
# Latest date: 2022-08-29 09:00:36+00:00
# Articles per year:
# pub_date
# 2022    500
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2022-05    131
# 2022-06    132
# 2022-07    134
# 2022-08    103
# Freq: M, Name: count, dtype: int64
#
# ==== NYT Apple 2024 01 - 2024 11 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 0    2024-09-10T09:05:34Z
# 1    2024-10-11T15:00:13Z
# 2    2024-09-23T09:00:25Z
# 3    2024-03-21T14:30:39Z
# 4    2024-10-31T21:10:57Z
# Name: pub_date, dtype: object
# Earliest date: 2024-01-03 18:21:13+00:00
# Latest date: 2024-11-29 12:00:14+00:00
# Articles per year:
# pub_date
# 2024    520
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2024-01     20
# 2024-02     24
# 2024-03     48
# 2024-04     25
# 2024-05     32
# 2024-06     41
# 2024-07     35
# 2024-08     55
# 2024-09     58
# 2024-10    107
# 2024-11     75
# Freq: M, Name: count, dtype: int64
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())

# %%
full_df = pd.concat([df_2122, df_2223, df_2325, df_0721, df_050822, df_011124], ignore_index=True)
full_df['pub_date'] = pd.to_datetime(full_df['pub_date'], errors='coerce')
full_df = full_df.sort_values('pub_date')
full_df = full_df.drop_duplicates(subset='web_url')

# %%
full_df
# Out:
#                                                   title  \
# 3000  What Happens if There’s a Covid Outbreak at th...
# 3001  This Conversation Will Change How You Think Ab...
# 3002  ‘The New Bauhaus’ Review: Rethinking an Approa...
# 1     Apple delays its return to office as the Delta...
# 3004                Can Apple’s AirTags Find Lost Pets?
# ...                                                 ...
# 2995  Jimmy Fallon Fans the Flames of Burning MAGA Hats
# 2996  How to Keep Love Alive, With Rob Delaney of ‘D...
# 2997                       Project 2025’s Other Project
# 2998  Tariffs Push Prices Up, and the Supreme Court’...
# 2999                                       Flood Season
#
#                                                 snippet  \
# 3000  Kara Swisher finds out why the 2020 Tokyo Game...
# 3001  Modern work culture is built on a broken model...
# 3002  This documentary on the interdisciplinary arti...
# 1     Employees are now expected to come back to the...
# 3004  We look at the pros and cons of using Apple’s ...
# ...                                                 ...
# 2995  People torched the hats in videos, apparently ...
# 2996  The Emmy-nominated actor talks about his role ...
# 2997  Inside the plan from the Heritage Foundation t...
# 2998       Plus, why that e-book cost your library $50.
# 2999  We look at recent flooding — and explain what ...
#
#                       pub_date  \
# 3000 2021-07-19 09:00:10+00:00
# 3001 2021-07-20 09:00:07+00:00
# 3002 2021-07-20 11:00:05+00:00
# 1    2021-07-20 15:42:40+00:00
# 3004 2021-07-20 16:06:15+00:00
# ...                        ...
# 2995 2025-07-16 06:42:23+00:00
# 2996 2025-07-16 09:00:29+00:00
# 2997 2025-07-16 10:00:10+00:00
# 2998 2025-07-16 10:00:12+00:00
# 2999 2025-07-16 11:07:17+00:00
#
#                                                 web_url     section  \
# 3000  https://www.nytimes.com/2021/07/19/opinion/swa...     Opinion
# 3001  https://www.nytimes.com/2021/07/20/opinion/ezr...     Opinion
# 3002  https://www.nytimes.com/2021/07/20/movies/the-...      Movies
# 1     https://www.nytimes.com/2021/07/20/technology/...  Technology
# 3004  https://www.nytimes.com/2021/07/20/technology/...  Technology
# ...                                                 ...         ...
# 2995  https://www.nytimes.com/2025/07/16/arts/televi...        Arts
# 2996  https://www.nytimes.com/2025/07/16/podcasts/ro...    Podcasts
# 2997  https://www.nytimes.com/2025/07/16/podcasts/th...    Podcasts
# 2998  https://www.nytimes.com/2025/07/16/podcasts/th...    Podcasts
# 2999  https://www.nytimes.com/2025/07/16/briefing/fl...    Briefing
#
#                   source
# 3000  The New York Times
# 3001  The New York Times
# 3002  The New York Times
# 1     The New York Times
# 3004  The New York Times
# ...                  ...
# 2995  The New York Times
# 2996  The New York Times
# 2997  The New York Times
# 2998  The New York Times
# 2999  The New York Times
#
# [3699 rows x 6 columns]

# %%
full_df = process_news_data(full_df, "NYT Apple 2021-2025")
# Out:
# ==== NYT Apple 2021-2025 ====
# Index(['title', 'snippet', 'pub_date', 'web_url', 'section', 'source'], dtype='object')
# 3000   2021-07-19 09:00:10+00:00
# 3001   2021-07-20 09:00:07+00:00
# 3002   2021-07-20 11:00:05+00:00
# 1      2021-07-20 15:42:40+00:00
# 3004   2021-07-20 16:06:15+00:00
# Name: pub_date, dtype: datetime64[ns, UTC]
# Earliest date: 2021-07-19 09:00:10+00:00
# Latest date: 2025-07-16 11:07:17+00:00
# Articles per year:
# pub_date
# 2021     565
# 2022    1021
# 2023     868
# 2024     590
# 2025     655
# Name: count, dtype: int64
# Articles per month:
# pub_date
# 2021-07     51
# 2021-08     70
# 2021-09    125
# 2021-10    117
# 2021-11    118
# 2021-12     84
# 2022-01    115
# 2022-02    101
# 2022-03    134
# 2022-04     82
# 2022-05    128
# 2022-06    132
# 2022-07    133
# 2022-08    103
# 2022-09     20
# 2022-10     20
# 2022-11     26
# 2022-12     27
# 2023-01     28
# 2023-02     36
# 2023-03     40
# 2023-04     48
# 2023-05     48
# 2023-06     89
# 2023-07     82
# 2023-08     76
# 2023-09    123
# 2023-10     97
# 2023-11    150
# 2023-12     51
# 2024-01     20
# 2024-02     24
# 2024-03     48
# 2024-04     25
# 2024-05     32
# 2024-06     40
# 2024-07     34
# 2024-08     55
# 2024-09     58
# 2024-10    106
# 2024-11     74
# 2024-12     74
# 2025-01    108
# 2025-02     89
# 2025-03     90
# 2025-04    117
# 2025-05    112
# 2025-06     86
# 2025-07     53
# Freq: M, Name: count, dtype: int64
# C:\Users\Juls\AppData\Local\Temp\ipykernel_9764\4062048410.py:28: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df['pub_date'].dt.to_period('M').value_counts().sort_index())

# %%
start_date = 20220901
end_date = 20230228
# Out:
# np.int64(0)
