# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("GNEWS_API")
BASE_URL = "https://gnews.io/api/v4/search"
QUERY = "AAPL stock OR Apple stock"
MAX_RESULTS_PER_CALL = 100

# Generate 1-month windows from today back to 2020-01-01
end_date = datetime.today()
start_date = datetime(2020, 1, 1)

date_ranges = []
while end_date > start_date:
    range_start = end_date - timedelta(days=30)
    if range_start < start_date:
        range_start = start_date
    date_ranges.append((range_start.strftime('%Y-%m-%d'), end_date.strftime('%Y-%m-%d')))
    end_date = range_start - timedelta(days=1)

# Load previously saved articles if they exist
try:
    existing_df = pd.read_csv("../data/gnews_partial.csv")
    completed_dates = set(pd.to_datetime(existing_df['publishedAt']).dt.strftime('%Y-%m'))
    all_articles = existing_df.to_dict("records")
except FileNotFoundError:
    all_articles = []
    completed_dates = set()

print(f"🟡 Skipping {len(completed_dates)} previously fetched windows.")

# Fetch articles month-by-month
for start, end in date_ranges:
    range_key = pd.to_datetime(start).strftime('%Y-%m')
    if range_key in completed_dates:
        print(f"✅ Skipping {range_key} (already done)")
        continue

    params = {
        'q': QUERY,
        'lang': 'en',
        'from': start,
        'to': end,
        'max': MAX_RESULTS_PER_CALL,
        'token': API_KEY,
    }

    print(f"📅 Fetching {start} to {end}...")
    try:
        response = requests.get(BASE_URL, params=params)
    except Exception as e:
        print(f"❌ Request error: {e}")
        continue

    if response.status_code == 200:
        data = response.json()
        articles = data.get('articles', [])
        print(f"🔹 Got {len(articles)} articles for {start} to {end}")

        for article in articles:
            all_articles.append({
                'title': article['title'],
                'description': article.get('description'),
                'content': article.get('content'),
                'publishedAt': article['publishedAt'],
                'source': article['source']['name'],
                'url': article['url']
            })

        # Save after each loop
        df = pd.DataFrame(all_articles)
        df.to_csv("../data/gnews_partial.csv", index=False)
        print(f"💾 Saved progress. Total articles: {len(df)}")

    elif response.status_code == 429:
        print("🚫 Rate limit hit! Stopping for today.")
        break

    else:
        print(f"⚠️ Failed to fetch ({response.status_code})")

    time.sleep(1)  # safety delay

print("✅ Done for now. You can rerun tomorrow to continue.")
# Out:
# 🟡 Skipping 0 previously fetched windows.
# 📅 Fetching 2025-06-20 to 2025-07-20...
# 🔹 Got 10 articles for 2025-06-20 to 2025-07-20
# 💾 Saved progress. Total articles: 10
# 📅 Fetching 2025-05-20 to 2025-06-19...
# 🔹 Got 10 articles for 2025-05-20 to 2025-06-19
# 💾 Saved progress. Total articles: 20
# 📅 Fetching 2025-04-19 to 2025-05-19...
# 🔹 Got 10 articles for 2025-04-19 to 2025-05-19
# 💾 Saved progress. Total articles: 30
# 📅 Fetching 2025-03-19 to 2025-04-18...
# 🔹 Got 10 articles for 2025-03-19 to 2025-04-18
# 💾 Saved progress. Total articles: 40
# 📅 Fetching 2025-02-16 to 2025-03-18...
# 🔹 Got 10 articles for 2025-02-16 to 2025-03-18
# 💾 Saved progress. Total articles: 50
# 📅 Fetching 2025-01-16 to 2025-02-15...
# 🔹 Got 10 articles for 2025-01-16 to 2025-02-15
# 💾 Saved progress. Total articles: 60
# 📅 Fetching 2024-12-16 to 2025-01-15...
# 🔹 Got 10 articles for 2024-12-16 to 2025-01-15
# 💾 Saved progress. Total articles: 70
# 📅 Fetching 2024-11-15 to 2024-12-15...
# 🔹 Got 10 articles for 2024-11-15 to 2024-12-15
# 💾 Saved progress. Total articles: 80
# 📅 Fetching 2024-10-15 to 2024-11-14...
# 🔹 Got 10 articles for 2024-10-15 to 2024-11-14
# 💾 Saved progress. Total articles: 90
# 📅 Fetching 2024-09-14 to 2024-10-14...
# 🔹 Got 10 articles for 2024-09-14 to 2024-10-14
# 💾 Saved progress. Total articles: 100
# 📅 Fetching 2024-08-14 to 2024-09-13...
# 🔹 Got 10 articles for 2024-08-14 to 2024-09-13
# 💾 Saved progress. Total articles: 110
# 📅 Fetching 2024-07-14 to 2024-08-13...
# 🔹 Got 10 articles for 2024-07-14 to 2024-08-13
# 💾 Saved progress. Total articles: 120
# 📅 Fetching 2024-06-13 to 2024-07-13...
# 🔹 Got 10 articles for 2024-06-13 to 2024-07-13
# 💾 Saved progress. Total articles: 130
# 📅 Fetching 2024-05-13 to 2024-06-12...
# 🔹 Got 10 articles for 2024-05-13 to 2024-06-12
# 💾 Saved progress. Total articles: 140
# 📅 Fetching 2024-04-12 to 2024-05-12...
# 🔹 Got 10 articles for 2024-04-12 to 2024-05-12
# 💾 Saved progress. Total articles: 150
# 📅 Fetching 2024-03-12 to 2024-04-11...
# 🔹 Got 10 articles for 2024-03-12 to 2024-04-11
# 💾 Saved progress. Total articles: 160
# 📅 Fetching 2024-02-10 to 2024-03-11...
# 🔹 Got 10 articles for 2024-02-10 to 2024-03-11
# 💾 Saved progress. Total articles: 170
# 📅 Fetching 2024-01-10 to 2024-02-09...
# 🔹 Got 10 articles for 2024-01-10 to 2024-02-09
# 💾 Saved progress. Total articles: 180
# 📅 Fetching 2023-12-10 to 2024-01-09...
# 🔹 Got 10 articles for 2023-12-10 to 2024-01-09
# 💾 Saved progress. Total articles: 190
# 📅 Fetching 2023-11-09 to 2023-12-09...
# 🔹 Got 10 articles for 2023-11-09 to 2023-12-09
# 💾 Saved progress. Total articles: 200
# 📅 Fetching 2023-10-09 to 2023-11-08...
# 🔹 Got 10 articles for 2023-10-09 to 2023-11-08
# 💾 Saved progress. Total articles: 210
# 📅 Fetching 2023-09-08 to 2023-10-08...
# 🔹 Got 10 articles for 2023-09-08 to 2023-10-08
# 💾 Saved progress. Total articles: 220
# 📅 Fetching 2023-08-08 to 2023-09-07...
# 🔹 Got 10 articles for 2023-08-08 to 2023-09-07
# 💾 Saved progress. Total articles: 230
# 📅 Fetching 2023-07-08 to 2023-08-07...
# 🔹 Got 10 articles for 2023-07-08 to 2023-08-07
# 💾 Saved progress. Total articles: 240
# 📅 Fetching 2023-06-07 to 2023-07-07...
# 🔹 Got 10 articles for 2023-06-07 to 2023-07-07
# 💾 Saved progress. Total articles: 250
# 📅 Fetching 2023-05-07 to 2023-06-06...
# 🔹 Got 10 articles for 2023-05-07 to 2023-06-06
# 💾 Saved progress. Total articles: 260
# 📅 Fetching 2023-04-06 to 2023-05-06...
# 🔹 Got 10 articles for 2023-04-06 to 2023-05-06
# 💾 Saved progress. Total articles: 270
# 📅 Fetching 2023-03-06 to 2023-04-05...
# 🔹 Got 10 articles for 2023-03-06 to 2023-04-05
# 💾 Saved progress. Total articles: 280
# 📅 Fetching 2023-02-03 to 2023-03-05...
# 🔹 Got 10 articles for 2023-02-03 to 2023-03-05
# 💾 Saved progress. Total articles: 290
# 📅 Fetching 2023-01-03 to 2023-02-02...
# 🔹 Got 10 articles for 2023-01-03 to 2023-02-02
# 💾 Saved progress. Total articles: 300
# 📅 Fetching 2022-12-03 to 2023-01-02...
# 🔹 Got 10 articles for 2022-12-03 to 2023-01-02
# 💾 Saved progress. Total articles: 310
# 📅 Fetching 2022-11-02 to 2022-12-02...
# 🔹 Got 10 articles for 2022-11-02 to 2022-12-02
# 💾 Saved progress. Total articles: 320
# 📅 Fetching 2022-10-02 to 2022-11-01...
# 🔹 Got 10 articles for 2022-10-02 to 2022-11-01
# 💾 Saved progress. Total articles: 330
# 📅 Fetching 2022-09-01 to 2022-10-01...
# 🔹 Got 10 articles for 2022-09-01 to 2022-10-01
# 💾 Saved progress. Total articles: 340
# 📅 Fetching 2022-08-01 to 2022-08-31...
# 🔹 Got 10 articles for 2022-08-01 to 2022-08-31
# 💾 Saved progress. Total articles: 350
# 📅 Fetching 2022-07-01 to 2022-07-31...
# 🔹 Got 10 articles for 2022-07-01 to 2022-07-31
# 💾 Saved progress. Total articles: 360
# 📅 Fetching 2022-05-31 to 2022-06-30...
# 🔹 Got 10 articles for 2022-05-31 to 2022-06-30
# 💾 Saved progress. Total articles: 370
# 📅 Fetching 2022-04-30 to 2022-05-30...
# 🔹 Got 10 articles for 2022-04-30 to 2022-05-30
# 💾 Saved progress. Total articles: 380
# 📅 Fetching 2022-03-30 to 2022-04-29...
# 🔹 Got 10 articles for 2022-03-30 to 2022-04-29
# 💾 Saved progress. Total articles: 390
# 📅 Fetching 2022-02-27 to 2022-03-29...
# 🔹 Got 10 articles for 2022-02-27 to 2022-03-29
# 💾 Saved progress. Total articles: 400
# 📅 Fetching 2022-01-27 to 2022-02-26...
# 🔹 Got 10 articles for 2022-01-27 to 2022-02-26
# 💾 Saved progress. Total articles: 410
# 📅 Fetching 2021-12-27 to 2022-01-26...
# 🔹 Got 10 articles for 2021-12-27 to 2022-01-26
# 💾 Saved progress. Total articles: 420
# 📅 Fetching 2021-11-26 to 2021-12-26...
# 🔹 Got 10 articles for 2021-11-26 to 2021-12-26
# 💾 Saved progress. Total articles: 430
# 📅 Fetching 2021-10-26 to 2021-11-25...
# 🔹 Got 10 articles for 2021-10-26 to 2021-11-25
# 💾 Saved progress. Total articles: 440
# 📅 Fetching 2021-09-25 to 2021-10-25...
# 🔹 Got 10 articles for 2021-09-25 to 2021-10-25
# 💾 Saved progress. Total articles: 450
# 📅 Fetching 2021-08-25 to 2021-09-24...
# 🔹 Got 10 articles for 2021-08-25 to 2021-09-24
# 💾 Saved progress. Total articles: 460
# 📅 Fetching 2021-07-25 to 2021-08-24...
# 🔹 Got 10 articles for 2021-07-25 to 2021-08-24
# 💾 Saved progress. Total articles: 470
# 📅 Fetching 2021-06-24 to 2021-07-24...
# 🔹 Got 10 articles for 2021-06-24 to 2021-07-24
# 💾 Saved progress. Total articles: 480
# 📅 Fetching 2021-05-24 to 2021-06-23...
# 🔹 Got 10 articles for 2021-05-24 to 2021-06-23
# 💾 Saved progress. Total articles: 490
# 📅 Fetching 2021-04-23 to 2021-05-23...
# 🔹 Got 10 articles for 2021-04-23 to 2021-05-23
# 💾 Saved progress. Total articles: 500
# 📅 Fetching 2021-03-23 to 2021-04-22...
# 🔹 Got 10 articles for 2021-03-23 to 2021-04-22
# 💾 Saved progress. Total articles: 510
# 📅 Fetching 2021-02-20 to 2021-03-22...
# 🔹 Got 10 articles for 2021-02-20 to 2021-03-22
# 💾 Saved progress. Total articles: 520
# 📅 Fetching 2021-01-20 to 2021-02-19...
# 🔹 Got 10 articles for 2021-01-20 to 2021-02-19
# 💾 Saved progress. Total articles: 530
# 📅 Fetching 2020-12-20 to 2021-01-19...
# 🔹 Got 10 articles for 2020-12-20 to 2021-01-19
# 💾 Saved progress. Total articles: 540
# 📅 Fetching 2020-11-19 to 2020-12-19...
# 🔹 Got 10 articles for 2020-11-19 to 2020-12-19
# 💾 Saved progress. Total articles: 550
# 📅 Fetching 2020-10-19 to 2020-11-18...
# 🔹 Got 10 articles for 2020-10-19 to 2020-11-18
# 💾 Saved progress. Total articles: 560
# 📅 Fetching 2020-09-18 to 2020-10-18...
# 🔹 Got 10 articles for 2020-09-18 to 2020-10-18
# 💾 Saved progress. Total articles: 570
# 📅 Fetching 2020-08-18 to 2020-09-17...
# 🔹 Got 10 articles for 2020-08-18 to 2020-09-17
# 💾 Saved progress. Total articles: 580
# 📅 Fetching 2020-07-18 to 2020-08-17...
# 🔹 Got 10 articles for 2020-07-18 to 2020-08-17
# 💾 Saved progress. Total articles: 590
# 📅 Fetching 2020-06-17 to 2020-07-17...
# 🔹 Got 10 articles for 2020-06-17 to 2020-07-17
# 💾 Saved progress. Total articles: 600
# 📅 Fetching 2020-05-17 to 2020-06-16...
# 🔹 Got 10 articles for 2020-05-17 to 2020-06-16
# 💾 Saved progress. Total articles: 610
# 📅 Fetching 2020-04-16 to 2020-05-16...
# 🔹 Got 10 articles for 2020-04-16 to 2020-05-16
# 💾 Saved progress. Total articles: 620
# 📅 Fetching 2020-03-16 to 2020-04-15...
# ⚠️ Failed to fetch (403)
# 📅 Fetching 2020-02-14 to 2020-03-15...
# ⚠️ Failed to fetch (403)
# 📅 Fetching 2020-01-14 to 2020-02-13...
# ⚠️ Failed to fetch (403)
# 📅 Fetching 2020-01-01 to 2020-01-13...
# ⚠️ Failed to fetch (403)
# ✅ Done for now. You can rerun tomorrow to continue.

# %%
import pandas as pd

daily_news = pd.read_csv("../data/gnews_partial.csv")
stock_df = pd.read_csv('../data/stock_data_4years.csv', skiprows=2)

stock_df.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

daily_news.head()
# Out:
#                                                title  \
# 0                             Today in Apple history
# 1  The AI Trade Is Back in Play: 2 Stocks to Buy ...
# 2  China Tariff Easing Spurs Stock Market Surge A...
# 3  Apple Faces New iPhone Fiasco as Update Bricks...
# 4  2 Reasons I'm Considering Apple Stock for a $2...
#
#                                          description  \
# 0  On June 18, 1993, Apple CEO John Sculley gave ...
# 1  Consider Apple (NASDAQ:AAPL) and another cheap...
# 2  The “dream scenario” for tech investors helped...
# 3  Apple (AAPL) faces another wave of challenges,...
# 4  Apple (NASDAQ:AAPL) stock looks like a deep-va...
#
#                                              content           publishedAt  \
# 0  June 18, 1993: John Sculley steps down as Appl...  2025-06-18T14:30:22Z
# 1  The AI (artificial intelligence) trade is gett...  2025-06-13T23:00:00Z
# 2  Topline Stocks surged across the board Monday ...  2025-05-12T04:00:00Z
# 3  Apple (AAPL) faces another wave of challenges,...  2025-04-27T16:35:02Z
# 4  The stock market has continued to experience a...  2025-04-23T14:00:00Z
#
#                    source                                                url
# 0             Cult of Mac  https://www.cultofmac.com/apple-history/john-s...
# 1  The Motley Fool Canada  https://www.fool.ca/2025/06/13/the-ai-trade-is...
# 2                  Forbes  https://www.forbes.com/sites/dereksaul/2025/05...
# 3        Business Insider  https://markets.businessinsider.com/news/stock...
# 4  The Motley Fool Canada  https://www.fool.ca/2025/04/23/2-reasons-im-co...

# %%
stock_df.head()
# Out:
#          Date       Close        High         Low        Open     Volume
# 0  2021-07-19  139.404251  140.989624  138.640930  140.676459  121434600
# 1  2021-07-20  143.025162  143.954862  139.903380  140.392689   96350000
# 2  2021-07-21  142.291168  143.005571  141.537642  142.418393   74993500
# 3  2021-07-22  143.661285  145.031346  142.692447  142.819672   77338200
# 4  2021-07-23  145.383606  145.540189  143.778672  144.395206   71447400

# %%
print(stock_df.shape)
print(stock_df.columns)
# Out:
# (1004, 6)
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
print(daily_news.shape)
print(daily_news.columns)
# Out:
# (620, 6)
# Index(['title', 'description', 'content', 'publishedAt', 'source', 'url'], dtype='object')

# %%
stock_df['date'] = pd.to_datetime(stock_df['Date']).dt.date

daily_news['date'] = pd.to_datetime(daily_news['publishedAt']).dt.date

# %%
stock_df
# Out:
#             Date       Close        High         Low        Open     Volume  \
# 0     2021-07-19  139.404251  140.989624  138.640930  140.676459  121434600
# 1     2021-07-20  143.025162  143.954862  139.903380  140.392689   96350000
# 2     2021-07-21  142.291168  143.005571  141.537642  142.418393   74993500
# 3     2021-07-22  143.661285  145.031346  142.692447  142.819672   77338200
# 4     2021-07-23  145.383606  145.540189  143.778672  144.395206   71447400
# ...          ...         ...         ...         ...         ...        ...
# 999   2025-07-11  211.160004  212.130005  209.860001  210.570007   39765800
# 1000  2025-07-14  208.619995  210.910004  207.539993  209.929993   38840100
# 1001  2025-07-15  209.110001  211.889999  208.919998  209.220001   42296300
# 1002  2025-07-16  210.160004  212.399994  208.639999  210.300003   47490500
# 1003  2025-07-17  210.020004  211.800003  209.589996  210.570007   48010700
#
#             date
# 0     2021-07-19
# 1     2021-07-20
# 2     2021-07-21
# 3     2021-07-22
# 4     2021-07-23
# ...          ...
# 999   2025-07-11
# 1000  2025-07-14
# 1001  2025-07-15
# 1002  2025-07-16
# 1003  2025-07-17
#
# [1004 rows x 7 columns]

# %%
daily_news
# Out:
#                                                  title  \
# 0                               Today in Apple history
# 1    The AI Trade Is Back in Play: 2 Stocks to Buy ...
# 2    China Tariff Easing Spurs Stock Market Surge A...
# 3    Apple Faces New iPhone Fiasco as Update Bricks...
# 4    2 Reasons I'm Considering Apple Stock for a $2...
# ..                                                 ...
# 615  Microsoft stock or Apple shares: Which is the ...
# 616  AAPL, JPM, GM: U.S. Stock Market Has Lost $11 ...
# 617  Morgan Stanley cut Apple price target over tar...
# 618  1 Essential "Magnificent 7" Stock for Canadian...
# 619  Apple vs. Shopify: Which Stock Is the Better B...
#
#                                            description  \
# 0    On June 18, 1993, Apple CEO John Sculley gave ...
# 1    Consider Apple (NASDAQ:AAPL) and another cheap...
# 2    The “dream scenario” for tech investors helped...
# 3    Apple (AAPL) faces another wave of challenges,...
# 4    Apple (NASDAQ:AAPL) stock looks like a deep-va...
# ..                                                 ...
# 615  Apple Inc (NASDAQ: AAPL) shares used to have t...
# 616  A total of $11.1 trillion has been wiped off t...
# 617  Morgan Stanley cut its price target on Apple (...
# 618  Apple (NASDAQ:AAPL) stands out as an intriguin...
# 619  Apple (NASDAQ:AAPL) and Shopify (TSX:SHOP) are...
#
#                                                content           publishedAt  \
# 0    June 18, 1993: John Sculley steps down as Appl...  2025-06-18T14:30:22Z
# 1    The AI (artificial intelligence) trade is gett...  2025-06-13T23:00:00Z
# 2    Topline Stocks surged across the board Monday ...  2025-05-12T04:00:00Z
# 3    Apple (AAPL) faces another wave of challenges,...  2025-04-27T16:35:02Z
# 4    The stock market has continued to experience a...  2025-04-23T14:00:00Z
# ..                                                 ...                   ...
# 615  Microsoft stock or Apple shares: Which is the ...  2025-04-11T04:06:46Z
# 616  A total of $11.1 trillion has been wiped off t...  2025-04-05T01:14:54Z
# 617  00:00 Speaker A\nApple getting a price target ...  2025-03-12T14:31:51Z
# 618  It’s hard to avoid the buzz about the Magnific...  2025-02-20T16:45:00Z
# 619  Canadian investors looking for long-term growt...  2024-12-14T01:00:00Z
#
#                      source  \
# 0               Cult of Mac
# 1    The Motley Fool Canada
# 2                    Forbes
# 3          Business Insider
# 4    The Motley Fool Canada
# ..                      ...
# 615   Motley Fool Australia
# 616        Business Insider
# 617           Yahoo Finance
# 618  The Motley Fool Canada
# 619  The Motley Fool Canada
#
#                                                    url        date
# 0    https://www.cultofmac.com/apple-history/john-s...  2025-06-18
# 1    https://www.fool.ca/2025/06/13/the-ai-trade-is...  2025-06-13
# 2    https://www.forbes.com/sites/dereksaul/2025/05...  2025-05-12
# 3    https://markets.businessinsider.com/news/stock...  2025-04-27
# 4    https://www.fool.ca/2025/04/23/2-reasons-im-co...  2025-04-23
# ..                                                 ...         ...
# 615  https://www.fool.com.au/2025/04/11/microsoft-s...  2025-04-11
# 616  https://markets.businessinsider.com/news/stock...  2025-04-05
# 617  https://finance.yahoo.com/video/morgan-stanley...  2025-03-12
# 618  https://www.fool.ca/2025/02/20/1-essential-mag...  2025-02-20
# 619  https://www.fool.ca/2024/12/13/apple-vs-shopif...  2024-12-14
#
# [620 rows x 7 columns]

# %%
# Combine title, description, and content into one text column
daily_news['text'] = (
    daily_news['title'].fillna('') + '. ' +
    daily_news['description'].fillna('') + '. ' +
    daily_news['content'].fillna('')
)

# Group all news per date into one big string (this gives one row per date)
grouped_news = daily_news.groupby('date')['text'].apply(lambda x: ' '.join(x)).reset_index()
grouped_news
# Out:
#          date                                               text
# 0  2024-12-14  Apple vs. Shopify: Which Stock Is the Better B...
# 1  2025-02-20  1 Essential "Magnificent 7" Stock for Canadian...
# 2  2025-03-12  Morgan Stanley cut Apple price target over tar...
# 3  2025-04-05  AAPL, JPM, GM: U.S. Stock Market Has Lost $11 ...
# 4  2025-04-11  Microsoft stock or Apple shares: Which is the ...
# 5  2025-04-23  2 Reasons I'm Considering Apple Stock for a $2...
# 6  2025-04-27  Apple Faces New iPhone Fiasco as Update Bricks...
# 7  2025-05-12  China Tariff Easing Spurs Stock Market Surge A...
# 8  2025-06-13  The AI Trade Is Back in Play: 2 Stocks to Buy ...
# 9  2025-06-18  Today in Apple history. On June 18, 1993, Appl...

# %%
merged_df = pd.merge(stock_df, grouped_news, on='date', how='left')

merged_df['text'] = merged_df['text'].fillna('')

# %%
merged_df
# Out:
#             Date       Close        High         Low        Open     Volume  \
# 0     2021-07-19  139.404251  140.989624  138.640930  140.676459  121434600
# 1     2021-07-20  143.025162  143.954862  139.903380  140.392689   96350000
# 2     2021-07-21  142.291168  143.005571  141.537642  142.418393   74993500
# 3     2021-07-22  143.661285  145.031346  142.692447  142.819672   77338200
# 4     2021-07-23  145.383606  145.540189  143.778672  144.395206   71447400
# ...          ...         ...         ...         ...         ...        ...
# 999   2025-07-11  211.160004  212.130005  209.860001  210.570007   39765800
# 1000  2025-07-14  208.619995  210.910004  207.539993  209.929993   38840100
# 1001  2025-07-15  209.110001  211.889999  208.919998  209.220001   42296300
# 1002  2025-07-16  210.160004  212.399994  208.639999  210.300003   47490500
# 1003  2025-07-17  210.020004  211.800003  209.589996  210.570007   48010700
#
#             date text
# 0     2021-07-19
# 1     2021-07-20
# 2     2021-07-21
# 3     2021-07-22
# 4     2021-07-23
# ...          ...  ...
# 999   2025-07-11
# 1000  2025-07-14
# 1001  2025-07-15
# 1002  2025-07-16
# 1003  2025-07-17
#
# [1004 rows x 8 columns]
